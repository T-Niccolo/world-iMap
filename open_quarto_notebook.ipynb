# %% [markdown]
# # Opening a New Quarto Notebook in Visual Studio Code
#
# This notebook demonstrates how to install Quarto, create a new Quarto notebook, and open it in Visual Studio Code.

# %% [markdown]
# ## 1. Install and Import Quarto
#
# You can install Quarto using pip (for Python environments) or download it from the official website. After installation, verify it with `quarto check`.

# %%
import ee

ee.Authenticate()
ee.Initialize(project="ee-orsperling")

# %% [markdown]
# ## 2. Create a New Quarto Notebook
#
# You can create a new Quarto notebook file (`.qmd`) using the terminal or the Quarto command line.

# %%
poi = ee.Geometry.Point([34.81261853908583, 31.392933669029375])

# %% [markdown]
# ## 3. Open the Quarto Notebook in Visual Studio Code
#
# You can open the newly created Quarto notebook using the VS Code file explorer or the command palette (`Cmd+P` or `Ctrl+P`).
